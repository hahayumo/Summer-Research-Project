# %% [markdown]
# # Obtain 4 true values of parameters for the Ornstein-Uhlenbeck process by calibrating the model to the real market pair stocks from S&P 500

# %%
import pandas as pd
import numpy as np
import random
from numpy.random import RandomState
from scipy import stats
from scipy.optimize import minimize
import os
os.environ['R_HOME'] = '/Library/Frameworks/R.framework/Versions/4.1/Resources/'
import rpy2
from rpy2.robjects.packages import importr
from rpy2.robjects.packages import SignatureTranslatedAnonymousPackage
import datetime
from rpy2.robjects.vectors import FloatVector
import multiprocessing

# %% [markdown]
# Define the model that generates pair simulations.

# %%
np.random.seed(9868)
yuima = importr("yuima")
n_ou_sim_string = """
n_sim_ou = function(random_seed, num_sim,
                    mu11, mu12, mu21, mu22,
                    sigma11, sigma12, sigma21, sigma22,
                    xinit, T0, T, length){
  
  set.seed(random_seed)
  
  drift = c("mu11-mu12*X1", "mu21-mu22*X2")
  diffusion = matrix(c("exp(sigma11)", "exp(sigma12)", "exp(sigma21)", "exp(sigma22)"), 2, 2, byrow=TRUE)
  ou_model = setModel(drift=drift, diffusion=diffusion, 
                        time.variable = "t",
                        state.var=c("X1","X2"), solve.variable=c("X1","X2"))
  
  newsamp = setSampling(Initial=T0, Terminal=T, n=length)
  
  n_sim_ou_data = data.frame(matrix(nrow=length+1, ncol=2*num_sim))
  for (i in 1:num_sim){
    ou_sim = simulate(ou_model, 
                      true.par=list(
                        mu11=mu11, mu12=mu12, mu21=mu21, mu22=mu22, 
                        sigma11=sigma11, sigma12=sigma12, sigma21=sigma21, sigma22=sigma22), 
                      xinit=xinit, sampling=newsamp)
    original_data = ou_sim@data@original.data
    one_sim_ou = data.frame(original_data[,1], original_data[,2])
    colnames(one_sim_ou) = c('series1', 'series2')
    n_sim_ou_data[, (2*i-1):(2*i)] = one_sim_ou
  }
  return(n_sim_ou_data)
}
"""

n_ou_sim = SignatureTranslatedAnonymousPackage(n_ou_sim_string, "n_ou_sim")
def n_ou_simulation(random_seed, num_sim,
                    mu11, mu12, mu21, mu22, sigma11, sigma12, sigma21, sigma22,
                    xinit, T0, T, length):
    """num_sim simulations of bivariate Ornstein-Uhlenbeck process,
    length = length of one series
    """
    n_ou_sim_data = pd.DataFrame(
        n_ou_sim.n_sim_ou(random_seed=random_seed, num_sim=num_sim,
                              mu11=mu11, mu12=mu12, mu21=mu21, mu22=mu22,
                              sigma11=sigma11, sigma12=sigma12, sigma21=sigma21, sigma22=sigma22,
                              xinit=xinit, T0=T0, T=T, length=length)).transpose()
    return n_ou_sim_data

# %% [markdown]
# Define some function that transforms price to return or the reverse.

# %%
def price_to_log_price(n_price):
    return(np.log(n_price))


def log_price_to_price(n_log_price):
    return(np.exp(n_log_price))


def price_to_return(n_price):
    n_return = pd.DataFrame()
    for i in range(n_price.shape[1]):
        ith_column_price_series = n_price.iloc[:, i]
        n_return = pd.concat([n_return, 100 * np.log(ith_column_price_series[1:].values / ith_column_price_series[:-1])], axis=1)
    return n_return


def log_price_to_return(n_log_price):
    n_real_return = pd.DataFrame()
    for i in range(n_log_price.shape[1]):
        ith_column_price_series = n_log_price.iloc[:, i]
        n_real_return = pd.concat([n_real_return, 100 * (ith_column_price_series[1:].values - ith_column_price_series[:-1])], axis=1)
    return n_real_return

# %% [markdown]
# Define the function of transforming returns data into feature statistics (or moments).

# %%
def cal_stats(n_return, n_price=None):
    """ 'mean' and 'sd' checked
    (different expressions of calculation from intro to stat finance)
    4 statistics
    """

    return_series1 = n_return.iloc[:, ::2]
    return_series2 = n_return.iloc[:, 1::2]

    mean1 = return_series1.mean(axis=0).values
    sd1 = return_series1.std(axis=0).values

    mean2 = return_series2.mean(axis=0).values
    sd2 = return_series2.std(axis=0).values

    stats_data = pd.DataFrame([mean1, mean2, sd1, sd2])
    stats_data = stats_data.transpose()
    stats_data.columns = [
        'return_mean1', 'return_mean2',
        'return_sd1', 'return_sd2']
    return stats_data

# %% [markdown]
# Define the loss function as the sum of the absolute differences between moments of real market return data and simulated return data

# %%
def loss_function(params):
    """n_real_stats is a global amount calculated outside the function"""

    params = FloatVector(params)
    moment_loss = pd.DataFrame().reindex_like(n_real_stats)

    randseed = np.random.randint(low=0, high=1000000, size=(1,))

    n_sim_log_price = n_ou_simulation(
        random_seed=int(randseed), num_sim=num_sim,
        mu11=mu11, mu12=params[0], mu21=mu21, mu22=params[1],
        sigma11=params[2], sigma12=sigma12, sigma21=sigma21, sigma22=params[3],
        xinit=xinit, T0=T0, T=T, length=length)

    n_sim_price = log_price_to_price(n_sim_log_price)
    n_sim_return = price_to_return(n_sim_price)
    n_sim_stats = cal_stats(n_sim_return)

    for i in range(n_real_stats.shape[0]):
        for j in range(n_real_stats.shape[1]):
            moment_loss.iloc[i, j] = np.sqrt((n_real_stats.iloc[i, j] - n_sim_stats.iloc[i, j])**2)

    sum_all = np.sum(moment_loss)
    return np.sum(sum_all)

# %% [markdown]
# Import the real market pair return data and prepare the corresponding initial log-prices of pair stocks for the following simulation and optimisation work.

# %%
# 4 params are: mu12, mu22, sigma11, sigma22

n_real_price = pd.read_csv("/Users/changmao/Desktop/real_pair_prices.csv", index_col=[0])
n_real_log_price = price_to_log_price(n_real_price)

n_real_return = pd.read_csv("/Users/changmao/Desktop/real_pair_returns.csv", index_col=[0])
n_real_stats = cal_stats(n_return=n_real_return, n_price=None)

# fixed constants are:
mu11, mu21, sigma12, sigma21 = 0, 0, -1000, -1000

xinit = [4, 5]

num_sim, T0, T, length = n_real_stats.shape[0], 0, 1, n_real_price.shape[0]
# num_sim 248 and length 250

# %% [markdown]
# The calibration process can be seen as a process of seeking for a set of values of the parameters such that the simulations are the closest to the real data in a sense that the feature statistics of simulations are matched with those of real returns such that the total losses  are minimised. Also, we will see the losses of moments.

# %%
np.random.seed(123)

initial0 = [1, 1, 1, 1]
    
# Look at the optimisation results
begin_time = datetime.datetime.now()
res = minimize(loss_function, initial0, method='Powell', 
               tol=1e-6, options={'disp': True})
print(res.x)
    
# Look at the running time
time = datetime.datetime.now() - begin_time
print(time)
    
# Look at the scales of losses of different moments
np.random.seed(9868)
params = (res.x)
params = FloatVector(params)
moment_loss = pd.DataFrame().reindex_like(n_real_stats)
randseed = np.random.randint(low=0, high=1000000, size=(1,))
n_sim_log_price = n_ou_simulation(
    random_seed=int(randseed), num_sim=num_sim,
    mu11=mu11, mu12=params[0], mu21=mu21, mu22=params[1],
    sigma11=params[2], sigma12=sigma12, sigma21=sigma21, sigma22=params[3],
    xinit=xinit, T0=T0, T=T, length=length)

n_sim_price = log_price_to_price(n_sim_log_price)
n_sim_return = price_to_return(n_sim_price)
n_sim_stats = cal_stats(n_sim_return)

for k in range(n_real_stats.shape[0]):
    for j in range(n_real_stats.shape[1]):
        moment_loss.iloc[k, j] = np.sqrt((n_real_stats.iloc[k, j] - 
                                          n_sim_stats.iloc[k, j])**2)
        
sum_all = np.sum(moment_loss)
print(sum_all)
# Out:
# Optimization terminated successfully.
#          Current function value: 236.433304
#          Iterations: 8
#          Function evaluations: 910
# [ 0.00681867  0.0532994  -1.36374583 -1.31715661]
# 0:26:33.987588
# return_mean1    25.642244
# return_mean2    31.027182
# return_sd1      79.613678
# return_sd2      99.689566
# dtype: float64

# %%
n_sim_price.to_csv("ou_4params_price.csv")
n_sim_return.to_csv("ou_4params_return.csv")

# %% [markdown]
# # Simulation Study

# %% [markdown]
# Set values. We will do a simulation study by generating pair series 1000 times with length of each series 250 (approx one-year data in real market).

# %%
random_seed = 9868

mu12, mu22, sigma11, sigma22 = params

num_sim, T0, T, length = 500, 0, 1, 250

# %% [markdown]
# Set the simulation generated from the model with the obtained parameters as the real data.

# %%
np.random.seed(9868)
n_real_log_price = n_ou_simulation(
    random_seed=random_seed, num_sim=num_sim,
    mu11=mu11, mu12=mu12, mu21=mu21, mu22=mu22,
    sigma11=sigma11, sigma12=sigma12, sigma21=sigma21, sigma22=sigma22,
    xinit=xinit, T0=T0, T=T, length=length)
n_real_price = log_price_to_price(n_log_price=n_real_log_price)
n_real_return = price_to_return(n_price=n_real_price)
n_real_stats = cal_stats(n_return=n_real_return, n_price=None)

# %% [markdown]
# See the effect on the losses by different moments

# %%
np.random.seed(9868)

params_vec = [(mu12, mu22, sigma11, sigma22),
              (mu12-1, mu22, sigma11, sigma22), (mu12-0.1, mu22, sigma11, sigma22), (mu12+1, mu22, sigma11, sigma22),
              (mu12, mu22-1, sigma11, sigma22), (mu12, mu22-0.1, sigma11, sigma22), (mu12, mu22+1, sigma11, sigma22),
              (mu12, mu22, sigma11-1, sigma22), (mu12, mu22, sigma11-0.1, sigma22), (mu12, mu22, sigma11+1, sigma22),
              (mu12, mu22, sigma11, sigma22-1), (mu12, mu22, sigma11, sigma22-0.1), (mu12, mu22, sigma11, sigma22+1)]
for i in params_vec:
    print(i, loss_function(i))
# Out:
# (0.03, 0.04, -1.41, -1.35) 188.50461925108038
# (-0.97, 0.04, -1.41, -1.35) 1509.232889264582
# (-0.07, 0.04, -1.41, -1.35) 233.91962687995013
# (1.03, 0.04, -1.41, -1.35) 626.9896560230982
# (0.03, -0.96, -1.41, -1.35) 1855.470807677079
# (0.03, -0.060000000000000005, -1.41, -1.35) 240.55999284327822
# (0.03, 1.04, -1.41, -1.35) 741.3089604905584
# (0.03, 0.04, -2.41, -1.35) 627.2582409174928
# (0.03, 0.04, -1.51, -1.35) 229.0217577842109
# (0.03, 0.04, -0.4099999999999999, -1.35) 1546.2582343574493
# (0.03, 0.04, -1.41, -2.35) 650.3190849154176
# (0.03, 0.04, -1.41, -1.4500000000000002) 229.02695020766777
# (0.03, 0.04, -1.41, -0.3500000000000001) 1620.8434839359497

# %% [markdown]
# We can iterate the optimisation 5 times and see the results.

# %%
def multi_process(iter):

    begin_time = datetime.datetime.now()
    print(begin_time)
    
    # look at the results of the optimisation
    res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
    print(res.x)
    
    # look at the time consumed
    time = datetime.datetime.now() - begin_time
    print(time)
    
    # look at the losses of moments
    moment_loss = pd.DataFrame().reindex_like(n_real_stats)
    randseed = np.random.randint(low=0, high=1000000, size=(1,))
    n_sim_log_price = n_ou_simulation(
            random_seed=int(randseed), num_sim=num_sim,
            mu11=mu11, mu12=params[0], mu21=mu21, mu22=params[1],
            sigma11=params[2], sigma12=sigma12, sigma21=sigma21, sigma22=params[3],
            xinit=xinit, T0=T0, T=T, length=length)

    n_sim_price = log_price_to_price(n_sim_log_price)
    n_sim_return = price_to_return(n_sim_price)
    n_sim_stats = cal_stats(n_sim_return)

    for i in range(n_real_stats.shape[0]):
        for j in range(n_real_stats.shape[1]):
            moment_loss.iloc[i, j] = np.sqrt((n_real_stats.iloc[i, j] - n_sim_stats.iloc[i, j])**2)

    sum_all = np.sum(moment_loss)
    print(sum_all)
    
    results.append([iter, res.x, time, sum_all])
    
    return res.x

# %%
np.random.seed(9868)
initial0 = [1, 1, 1, 1]
results = []

num_iter = [i for i in range(500)]
pool = multiprocessing.Pool()
result = pool.map(multi_process, num_iter)
# Out:
# 2021-08-06 20:38:20.0700092021-08-06 20:38:20.0702332021-08-06 20:38:20.0700072021-08-06 20:38:20.0702512021-08-06 20:38:20.0700442021-08-06 20:38:20.0703002021-08-06 20:38:20.0700392021-08-06 20:38:20.070251
#
#
#
#
#
#
#
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:42:55.984409
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:42:57.725914
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:02.537486
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:03.628881
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:24.383572
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:25.304094
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:08.619747
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:08.887261
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:09.875695
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:31.073488
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:31.725206
# Optimization terminated successfully.
#          Current function value: 188.097720
#          Iterations: 3
#          Function evaluations: 302
# [ 0.04410363  0.05823872 -1.40599106 -1.35634101]
# 0:43:14.244604
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:38.286849
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:38.375994
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:40.191159
# return_mean1    52.182485
# return_mean2    53.962628
# return_sd1      39.789250
# return_sd2      42.609715
# dtype: float64
# 2021-08-06 21:21:44.607363
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-23:
# From cffi callback Process ForkPoolWorker-17:
# From cffi callback Process ForkPoolWorker-21:
# <function _processevents at 0x7fa3083b9d40>From cffi callback Traceback (most recent call last):
# Process ForkPoolWorker-24:
# Traceback (most recent call last):
# <function _processevents at 0x7fa3083b9d40>:
# <function _processevents at 0x7fa3083b9d40>  File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d9710e29ca7f> in <module>
#       5 num_iter = [i for i in range(500)]
#       6 pool = multiprocessing.Pool()
# ----> 7 result = pool.map(multi_process, num_iter)
#
# /opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# /opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# /opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /opt/homebrew/anaconda3/envs/venv37/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /opt/homebrew/anaconda3/envs/venv37/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# :
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# :
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#           File "<ipython-input-19-f2af70eb60d8>", line 7, in multi_process
#     res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
#   File "<ipython-input-19-f2af70eb60d8>", line 7, in multi_process
#     res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
#       File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# @ffi_proxy.callback(ffi_proxy._processevents_def,  File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 610, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
# @ffi_proxy.callback(ffi_proxy._processevents_def,@ffi_proxy.callback(ffi_proxy._processevents_def,  File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 610, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
#   File "<ipython-input-19-f2af70eb60d8>", line 7, in multi_process
#     res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
#   File "<ipython-input-19-f2af70eb60d8>", line 7, in multi_process
#     res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
#   File "<ipython-input-19-f2af70eb60d8>", line 7, in multi_process
#     res = minimize(loss_function, initial0, method='Powell', tol=1e-6, options={'disp': True})
#
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2969, in _minimize_powell
#     fval=fval)
#
#
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2969, in _minimize_powell
#     fval=fval)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 610, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 610, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 610, in minimize
#     return _minimize_powell(fun, x0, args, callback, bounds, **options)
# KeyboardInterrupt  File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2696, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
# KeyboardInterruptKeyboardInterrupt  File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2696, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2969, in _minimize_powell
#     fval=fval)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2969, in _minimize_powell
#     fval=fval)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2969, in _minimize_powell
#     fval=fval)
#
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2298, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#
#
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2298, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2696, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2696, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2696, in _linesearch_powell
#     alpha_min, fret, _, _ = brent(myfunc, full_output=1, tol=tol)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2330, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2330, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2298, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2298, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2298, in brent
#     res = _minimize_scalar_brent(func, brack, args, **options)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2114, in optimize
#     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2114, in optimize
#     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2330, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2330, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2330, in _minimize_scalar_brent
#     brent.optimize()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2088, in get_bracket_info
#     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2088, in get_bracket_info
#     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2121, in optimize
#     fw = fv = fx = func(*((x,) + self.args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2114, in optimize
#     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2114, in optimize
#     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2544, in bracket
#     fc = func(*((xc,) + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2539, in bracket
#     fb = func(*(xb,) + args)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2689, in myfunc
#     return func(p + alpha*xi)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2088, in get_bracket_info
#     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2689, in myfunc
#     return func(p + alpha*xi)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2088, in get_bracket_info
#     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2689, in myfunc
#     return func(p + alpha*xi)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 461, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 461, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2544, in bracket
#     fc = func(*((xc,) + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2544, in bracket
#     fc = func(*((xc,) + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 461, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "<ipython-input-13-a8008b4105cb>", line 16, in loss_function
#     n_sim_return = price_to_return(n_sim_price)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2689, in myfunc
#     return func(p + alpha*xi)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 2689, in myfunc
#     return func(p + alpha*xi)
#   File "<ipython-input-13-a8008b4105cb>", line 16, in loss_function
#     n_sim_return = price_to_return(n_sim_price)
#   File "<ipython-input-13-a8008b4105cb>", line 21, in loss_function
#     moment_loss.iloc[i, j] = np.sqrt((n_real_stats.iloc[i, j] - n_sim_stats.iloc[i, j])**2)
#   File "<ipython-input-11-6771bd498e7d>", line 13, in price_to_return
#     n_return = pd.concat([n_return, 100 * np.log(ith_column_price_series[1:].values / ith_column_price_series[:-1])], axis=1)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexing.py", line 689, in __setitem__
#     self._has_valid_setitem_indexer(key)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 461, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 461, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "<ipython-input-11-6771bd498e7d>", line 13, in price_to_return
#     n_return = pd.concat([n_return, 100 * np.log(ith_column_price_series[1:].values / ith_column_price_series[:-1])], axis=1)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 295, in concat
#     sort=sort,
#   File "<ipython-input-13-a8008b4105cb>", line 13, in loss_function
#     xinit=xinit, T0=T0, T=T, length=length)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexing.py", line 1392, in _has_valid_setitem_indexer
#     for ax, i in zip(self.obj.axes, indexer):
#   File "<ipython-input-13-a8008b4105cb>", line 13, in loss_function
#     xinit=xinit, T0=T0, T=T, length=length)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 295, in concat
#     sort=sort,
#   File "<ipython-input-10-cfe91815ef7f>", line 46, in n_ou_simulation
#     xinit=xinit, T0=T0, T=T, length=length)).transpose()
#   File "<ipython-input-10-cfe91815ef7f>", line 46, in n_ou_simulation
#     xinit=xinit, T0=T0, T=T, length=length)).transpose()
# KeyboardInterrupt
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 467, in __init__
#     self.new_axes = self._get_new_axes()
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 451, in __init__
#     obj = sample._constructor({name: obj})
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/frame.py", line 570, in __init__
#     arrays, columns = to_arrays(data, columns, dtype=dtype)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/frame.py", line 570, in __init__
#     arrays, columns = to_arrays(data, columns, dtype=dtype)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 539, in _get_new_axes
#     for i in range(ndim)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 551, in to_arrays
#     data = [tuple(x) for x in data]
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/frame.py", line 529, in __init__
#     mgr = init_dict(data, index, columns, dtype=dtype)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 552, in to_arrays
#     return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 277, in init_dict
#     columns = data_names = Index(keys)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 539, in <listcomp>
#     for i in range(ndim)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 551, in <listcomp>
#     data = [tuple(x) for x in data]
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 569, in _list_to_arrays
#     result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 549, in _get_comb_axis
#     copy=self.copy,
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 256, in __new__
#     name = maybe_extract_name(name, data, cls)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py", line 664, in __iter__
#     yield self[i]
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 736, in _convert_object_array
#     arrays = [convert(arr) for arr in content]
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/api.py", line 92, in get_objs_combined_axis
#     return _get_combined_index(obs_idxes, intersect=intersect, sort=sort, copy=copy)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 736, in <listcomp>
#     arrays = [convert(arr) for arr in content]
# KeyboardInterrupt
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/robjects/vectors.py", line 265, in __getitem__
#     res = super().__getitem__(i)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 732, in convert
#     arr = lib.maybe_convert_objects(arr, try_float=coerce_float)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/api.py", line 145, in _get_combined_index
#     index = union_indexes(indexes, sort=sort)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/rpy2/rinterface.py", line 454, in __getitem__
#     res = openrlib.REAL_ELT(cdata, i_c)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/api.py", line 217, in union_indexes
#     result = result.union(other)
#   File "pandas/_libs/lib.pyx", line 2176, in pandas._libs.lib.maybe_convert_objects
# KeyboardInterrupt
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2700, in union
#     return self._union_incompatible_dtypes(other, sort=sort)
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/numpy/core/numeric.py", line 288, in full
#     @set_array_function_like_doc
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2618, in _union_incompatible_dtypes
#     return Index.union(this, other, sort=sort).astype(object, copy=False)
# KeyboardInterrupt
#   File "/opt/homebrew/anaconda3/envs/venv37/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 665, in astype
#     def astype(self, dtype, copy=True):
# KeyboardInterrupt

# %% [markdown]
# See the mean and standard deviation of the optimisation results.

# %%
results_res = []
results_time = []
results_sum_all = []
for i in results:
    results_res.append(i[0])
    results_time.append(i[1])
    results_sum_all.append(i[2])

res_mean = pd.DataFrame(results_res).mean(axis=0)
res_std  = pd.DataFrame(results_res).std(axis=0)
print(res_mean)
print(res_std)

# %%
params
